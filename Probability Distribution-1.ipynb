# %% [markdown]
# ### Binomial distribution
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment; for example, when you flip a coin, it can be either head or tails.

# %%
import numpy as np

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %% [markdown]
# ### Uniform Distribution

# %%
from scipy.stats import uniform

#create uniform dist function for point estimate
def unif_dist(x, low= 0, high=10):
    result = uniform.pdf(x, loc = low, scale=high)
    return result

#create cumulative distribtion 
def cum_dist(q, low = 0, high = 10):
    result = uniform.cdf(q, loc = low, scale=high)
    return result

#create percentile point distribution 
def quant_uniform(p, low = 0, high = 10):
    result = uniform.ppf(q = p, loc = low, scale=high)
    return result
#random variable distribtuion 
def rand_unif(n, low = 0, high = 10):
    result = uniform.rvs(loc = low, scale=high, size = n)
    return result

# %%
import matplotlib.pyplot as plt


#implement functions Noraml 
data = np.linspace(-10, 10, num=1000)

#implement functions Uniform
point = normal_dist(data, mean = mean, std = std)
cumulative = cum_normal(data, mean = mean, std =std)
quant = percentile_point(data, mean = mean, std=std)


fig, ax = plt.subplots(3, 1, figsize = (10,10))
ax[0].plot(data, point, "r-")
ax[1].plot(data, cumulative, "b-")
ax[2].plot(data, quant, "g-")

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Normal Distributions

# %%
from scipy.stats import norm

#normal distribution
def normal_dist(x, mean=0, std = 1):
    return norm.pdf(x, loc=mean, scale=std)

#cumulative normal dist
def cum_normal(x, mean=0, std = 1):
    return norm.cdf(x=x, loc=mean, scale=std)

#percentile point 
def percentile_point(p, mean=0, std = 1):
    return norm.ppf(q = p, loc=mean, scale= std)


#random variable
def random_variable(n, mean=0, std = 1):
    return norm.rvs(n, loc=mean, scale=std)

# %%
random_numbers = np.random.seed(42)

#define variables
mean = 0
std = 1 
data = np.linspace(-10, 10, num=1000)


#implement functions Uniform
point_uniform = normal_dist(data, mean = mean, std = std)
cumulative_uniform = cum_normal(data, mean = mean, std =std)
quant_uniform = percentile_point(data, mean = mean, std=std)


#implement functions Noraml 


fig, ax = plt.subplots(3, 1, figsize = (10,10))
ax[0].stem(data, point_uniform, "r-")
ax[1].stem(data, cumulative_uniform, "b-")
ax[2].stem(data, quant_uniform, "g-")


plt.show()
